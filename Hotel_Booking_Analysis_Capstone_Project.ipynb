# %% [markdown]
# <a href="https://colab.research.google.com/github/YashwantRaul/EDA-of-Hotel-booking/blob/main/Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ##**Project Overview:**
# We will perform exploratory data analysis with **Hotel Booking Dataset**.
#
#  This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.
#  We have to analyze the data with considering aboove prolem statement.

# %% [markdown]
# ##**Import Require Libraries**

# %%
# import all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ##**Mount The Drive And Import Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the Dataset
working_dir_path = "/content/drive/MyDrive/Almabetter/Capstone Project/Project1-EDA/Hotel Booking Analysis/Hotel Bookings.csv"
dataset = pd.read_csv(working_dir_path)

# %% [markdown]
# ##**Data Exploration**

# %%
# Creating copy of data so that there will be no change in original dataset
df = dataset.copy()

# %%
# Getting dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Summary of dataframe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# In above summary, Min of adr(Average daily rates) is negative, means some values of adr is negative which misleading data

# %%
# Getting top 5 rows
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Getting last 5 rows
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Looking for NaN/Null/Missing from each columns
df.isna().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %% [markdown]
# ##**Data cleaning**

# %%
# Drop the column company and agent from the dataframe
df.drop(['company','agent'],inplace=True,axis=1)

# %%
# filling all null values with 0 in column children
df['children'] = df['children'].fillna(0.0)

# convert datatype from float to int in column children
df['children'] = df['children'].astype(int)

# %%
# Replace the null values of country column with mode value
df['country'].fillna(df['country'].mode().to_string(), inplace=True)

# %%
# Drop the Rows where guests not available
df = df.drop(df[(df.adults+df.babies+df.children)==0].index)

# %%
# replace all negative values in adr by 0
df.loc[df.adr <= 0, 'adr'] =df['adr'].fillna(0, inplace=True)

# %% [markdown]
# **Now, let's create a another new dataframe with specific column that give information which required for analysing data & help to  work on above problem statement.**

# %%
# Available columns in main dataframe 
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# lets add some new columns
df['total_people'] = df['adults'] + df['babies'] + df['children']   
df['length_of_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
# Create new dataframe with specific columns which require for future analysis
req_columns = ['hotel', 'is_canceled', 'arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'total_people', 'length_of_stay', 'country','market_segment', 'deposit_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status']
df_new = df[req_columns]

# %% [markdown]
# ###We are done with all missing/null/na values, getting proper datatype of some column, reomving no guests rows, handelling adr values appropriately & create new dataframe with specific columns.

# %% [markdown]
# ##**EDA (Exploratory Data Analysis)**

# %% [markdown]
# ###**Q1: Which type of hotel mostely prefered by guest ?**

# %%
# get types of hotel
types_of_hotel = df_new.hotel.unique()
print(f"Types of hotel: {types_of_hotel}.")
# Out:
# Types of hotel: ['Resort Hotel' 'City Hotel'].

# %%
df_new.groupby('hotel').size().plot(kind='pie', labels=["City Hotel", "Resort Hotel"], fontsize=16,  figsize=(5, 5), autopct='%.2f%%',)
plt.title('Types of hotel prefered', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Types of hotel prefered')

# %% [markdown]
# ###Max booking in city hotel that means customer prefered City Hotel.

# %% [markdown]
# ###**Q2: In which year highest booking made ?**

# %%
# get ratio of both hotels year wise
year_wise_booking_ratio = df_new["arrival_date_year"].value_counts()
year_wise_booking_ratio.plot.pie(figsize = (5,5),fontsize = 16, autopct="%.1f%%")
plt.title('Year wise booking ratio of hotels in percentage',fontsize = 20)
plt.ylabel('Bookings percentage',fontsize = 16)
plt.xlabel('Year of hotels booking',fontsize = 16)
# Out:
# Text(0.5, 0, 'Year of hotels booking')

# %% [markdown]
# ###Bookings for year 2016 were highest with 48%. Bookings were increasing on yearly basis. For year 2016 increment was too high so there was steep fall in bookings for year 2017.

# %% [markdown]
# ###**Q3: In Which month highest booking made?**

# %%
# Month wise bookings for each type of hotel
plt.rcParams['figure.figsize']= (15,7)
sns.countplot(data = df_new, x = 'arrival_date_month', hue = 'hotel', order= [ 'January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])
plt.title('Monthly Bookings: Resort Hotel vs. City Hotel',fontsize=20)
plt.xlabel('Month', fontsize=16)
plt.ylabel('No. of Bookings', fontsize=16)
# Out:
# Text(0, 0.5, 'No. of Bookings')

# %% [markdown]
# ###In month of August saw the highest number of hotel bookings for both type of hotels.The lowest hotel bookings were in January.

# %% [markdown]
# ###**Q4: What are the pecentage of cancellation?**

# %%
# How many bookings is cancelled and not cancelled in percent(%)
df_new['is_canceled'].value_counts().plot.pie( autopct='%.f%%', figsize=(5,5),fontsize=16)
plt.title('Comparison of  Cancelled and Non Cancelled Bookings In Percent (%)', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of  Cancelled and Non Cancelled Bookings In Percent (%)')

# %% [markdown]
# ###0= not cancled,1= canceled.
# ###37 % of the bookings were cancelled.

# %% [markdown]
# ### **Q5: Which type of hotel having higher rate of cancelation?**

# %%
# Canceled and Non canceled bookings for each type of hotel
plt.rcParams['figure.figsize']= (10,5)
sns.countplot(data = df_new, x = 'is_canceled', hue= 'hotel')
plt.title('Booking Cancelation: City Hotel vs. Resort Hotel',fontsize=20)
plt.xlabel('Booking Cancelation status', fontsize=16)
plt.ylabel('No. of Bookings', fontsize=16)
# Out:
# Text(0, 0.5, 'No. of Bookings')

# %% [markdown]
# ###Cancelation of bookings in city hotel were higher than resort hotel.

# %% [markdown]
# ###**Q6: What is Percentage distribution of Deposite type?**

# %%
#deposit_type
round(df_new['deposit_type'].value_counts(normalize=True) * 100, 2)
df_new.groupby('deposit_type').size().plot(kind='pie', fontsize=15, autopct='%.2f',  figsize=(5, 5))
plt.ylabel('' , fontsize=16)
plt.title('Types of Deposit', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Types of Deposit')

# %% [markdown]
# ###About 87.63% bookings are without any deposit. 12.24% bookings deposit are non refundable.Guests prefered no deposit type bookings because flexibility to cancel or change bookings without losing any money.

# %% [markdown]
# ###**Q7: What is relationship between deposited type & cancelation?**

# %%
# Relationship between Deposit type and Cancelation
plt.rcParams['figure.figsize']= (10,5)
sns.countplot(data = df_new, x = 'deposit_type', hue='is_canceled')
plt.title('Relationship between Deposit type and Cancelation', fontsize=20)
plt.xlabel('Deposite type', fontsize=16)
plt.ylabel('Booking Cancelation status', fontsize=16)
# Out:
# Text(0, 0.5, 'Booking Cancelation status')

# %% [markdown]
# ###That could explain why the booking with no deposit was higher.So we can say that guests who do not pay any deposit while booking are likely to cancel more reservations.

# %% [markdown]
# ###**Q8: Which Hotel type has  the highest ADR?**

# %%
# Relation between Hotel type and Adr
highest_adr=df_new.groupby(['hotel'])['adr'].mean().reset_index()
plt.rcParams['figure.figsize']= (10,5)
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
plt.title("Avg ADR of each Hotel type", fontsize=20)
plt.xlabel('Hotel type', fontsize=16)
plt.ylabel('ADR', fontsize=16)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ###City hotel has the highest ADR. That means city hotels are generating more revenues than the resort hotels

# %% [markdown]
# ###**Q9: Whats is best time in year to book hotel?**

# %%
#Average Daily Rate monthwise
plt.rcParams['figure.figsize']= (15,7)
sns.lineplot(data = df_new, x = 'arrival_date_month', y='adr', hue = 'hotel', marker='o')
plt.title('Monthly Bookings: Resort Hotel vs. City Hotel',fontsize=20)
plt.xlabel('Month', fontsize=16)
plt.ylabel('ADR', fontsize=16)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ###For both city and resort hotels, Nov to Jan have cheaper average daily rates so this is the best time of year to book a hotel . Also we can see prices for resort hotels are higher and fluctuate more than city hotels.

# %% [markdown]
# ###**Q10: How many no. of stays in week nights were prefered by most of the guests?**

# %%
#getting length of stay in week night
df_new['stays_in_week_nights'].value_counts().sort_index()[1:11].plot(kind='line', figsize=(10,5),marker='o')
plt.xlabel('Days' , fontsize=15)
plt.ylabel('Bookings' , fontsize=15)
plt.title('Stays in week nights Vs. Bookings', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Stays in week nights Vs. Bookings')

# %% [markdown]
# ###Most of the bookings were for 2 night stays in week nights.

# %% [markdown]
# ###**Q11: How many no. of stays in weekend nights were prefered by most of the guests?**

# %%
#getting length of stay in weekend night
df_new['stays_in_weekend_nights'].value_counts().sort_index()[1:11].plot(kind='line', figsize=(10,5), marker='o')
plt.xlabel('Days' , fontsize=16)
plt.ylabel('Bookings' , fontsize=15)
plt.title('Stays in weekend nights Vs. Bookings', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Stays in weekend nights Vs. Bookings')

# %% [markdown]
# ###Most of the bookings were for 2 night stays in weekend nights.

# %% [markdown]
# ###**Q11: What is optimal length of stay in order to get the best daily rate?**

# %%
# length of stay for both hotel type
plt.rcParams['figure.figsize']= (15,7)
sns.countplot(data = df_new, x = 'length_of_stay',hue='hotel')
plt.title('Optimal length of stay ',fontsize=20)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Bookings', fontsize=16)
# Out:
# Text(0, 0.5, 'Bookings')

# %% [markdown]
# ###Optimal stay in both the type hotel is less than 7 days but For long stay guest prefer Resort hotel.

# %% [markdown]
# ###**Q12: What is length of stay in order to get the best daily rate?**

# %%
# length of stay for both hotel type
plt.rcParams['figure.figsize']= (15,7)
sns.lineplot(data = df_new, x = 'length_of_stay',y='adr',hue='hotel', marker='o')
plt.title('Relationship between adr and total stay',fontsize=20)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Average daily rates', fontsize=16)
# Out:
# Text(0, 0.5, 'Average daily rates')

# %% [markdown]
# ###As increse in length of stay, adr gets decreases. To get best adr need to stay more than Month.

# %% [markdown]
# ###**Q13: Which type of market segment having more involvement?**

# %%
# market segment wise involvement in booking
plt.rcParams['figure.figsize']= (10,5)
sns.countplot(x ='market_segment', data = df_new).plot(kind='bar', figsize=(8,5))
plt.title('Segments wise hotel bookings', fontsize=20)
plt.xlabel('Market Segments', fontsize=16)
plt.ylabel('Bookings', fontsize=16)
# Out:
# Text(0, 0.5, 'Bookings')

# %% [markdown]
# ###More involvement in bookings with Online TA and Offline TA/TO that means maximum hotel are booked with agents only.

# %% [markdown]
# ###**Q14:What is the percentage distribution of required_car_parking_spaces?**

# %%
# requirement of car parking space
df_new['required_car_parking_spaces'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(5,5),fontsize=16,labels=None)
labels=df_new['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces',fontsize = 20)
# Out:
# Text(0.5, 1.0, '% Distribution of required car parking spaces')

# %% [markdown]
# ###Almost 94% of bookings, there is no requirement for car parking spaces.
# ###Alomst 5.83% of bookings' there is requirement of one car parking space.

# %% [markdown]
# ###**Q15: How many special requests are there for booking?**

# %%
# booking with special request
df_new.groupby('total_of_special_requests').size()[:4].plot(kind='pie', labels=["No special request", 1, 2, 3], fontsize=12, autopct='%.2f%%',  figsize=(6, 6))
plt.xlabel('Percentage' , fontsize=16)
plt.title('Total Special Request', fontsize=16)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', labels=labels)

# %% [markdown]
# ###About 59% of bookings there are no special requests. 27.92% of bookings there is one special request.

# %% [markdown]
# ###**Q16: What is the reservation_status?**

# %%
# reservation status
df_new.groupby('reservation_status').size().plot(kind='pie', fontsize=15, autopct='%.2f%%',  figsize=(6, 6))
plt.ylabel('' , fontsize=16)
plt.title('Reservation Status', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Reservation Status')

# %% [markdown]
# ###36% of bookings got canceled.
# ###1% of bookings never arrived at hotel without cancelling bookings

# %% [markdown]
# ###**From which countries the most guests are coming?

# %%
# countries from where most of guest are coming
plt.rcParams['figure.figsize']= (15,7)
sns.barplot (y= list(df_new.country.value_counts().head (20)), x= list(df_new.country.value_counts().head(20).index))
plt.title('Countries with Highest Bookings', fontsize=20)
plt.xlabel('Country name', fontsize=16)
plt.ylabel('No. of Bookings', fontsize=16)
# Out:
# Text(0, 0.5, 'No. of Bookings')

# %% [markdown]
# ###Most of the guest are coming from Portugal(PRT),Great Britain(GRB), France(FRA),Spain(ESP) and Germany(DEU).

# %% [markdown]
# ##**Correlation of data**

# %%
# getting correlated dataframe
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True)
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
#
# ###*  Lead_time and total_stay is positively correlated.That means more is the stay of cutsomer more will be the lead time.
# ###*   Total people are positively correlated to each other. As increase in people ADR will be more.
# ###*   is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are not more likely to cancel their bookings.
# ###*   As incrrease in special request ADR will be more
# ###*   Special request are more for an adult

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ###We used the dataset which contains data about hotel bookings. We cleaned and preprocessed the data and then we performed the exploratory data analysis to extract information from the given data to get some results and final conclusions.
#
# ###**Following are the results and conclusions:-**
#
# ###City hotels having maximum booking, which are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
#
# ###Considering the years, Bookings for year 2016 were highest with 48%. Bookings were increasing on yearly basis. For year 2016 increment was too high so there was steep fall in bookings for year 2017.
#
# ###In month of August saw the highest number of hotel bookings for both type of hotels.The lowest hotel bookings were in January. Daily rates are also high in month of August Where low in january so january is the best time to book a hotel with cheaper rate & confirmed booking.
#
# ###Guests prefered no deposit type bookings because flexibility to cancel or change bookings without losing any money. About 87.63% bookings are without any deposit. 12.24% bookings deposit are non refundable.
#
# ###Out of total booking 37% booking were cancelled. With high no. of booking, cancellation is also higher in city hotel and out of that cancelled booking, hotel with no deposit having higher cancellation rate.
# ###Repeated guests are not more likely to cancel their bookings.
#
# ###Considering the rates City hotel has the highest ADR. That means city hotels are generating more revenues than the resort hotels.
#
# ###Most of the people prefer 2 night stay. Optimal length of stay is 7 days. as increase in length of stay ADR gets decreases.To get best adr need to stay more than month.
# ###For long stay guest prefer resort hotel.
#
# ###More involvement in bookings with Online TA and Offline TA/TO that means maximum hotel are booked with agents only.
#
# ###Special request are more for an adult. As increase in special request and increasing in people ADR will be  more.
#
# ###Most of the guest are coming from Portugal(PRT),Great Britain(GRB), France(FRA),Spain(ESP) and Germany(DEU).
#
# ###Finally checkout the reservation status, 36% of bookings got canceled.1% of bookings never arrived at hotel without cancelling bookings.
